# %%
import tabula
import pandas as pd
tabula.convert_into("OC_LEITOS_UND_20200601.pdf","OC_LEITOS_UND.csv",output_format = "csv",pages = "1")
dfLeitosUnd = pd.read_csv('OC_LEITOS_UND.csv',header=None)
#renomear as colunas
#dfLeitos.columns = ['unidade/indicador','total_sala_vermelha','sala_vermelha_covid','sala_vermelha_naocovid','total_leitos_clinicos','leitos_clinicos_covid','total_leitos_clinicos_naocovid','oc_leitos_clinicos_naocovid','livres_leitos_clinicos_naocovid','total_uti','leitos_uti_covid','leitos_uti_naocovid','taxa_ocupacao']


#dfLeitosUnd[['total_sala_vermelha','oc_sala_vermelha','livres_sala_vermelha']]= dfLeitosUnd['sala_vermelha_covid'].str.split(' ', n=3, expand=True)

dfLeitosUnd
# Out:
#                                              0           1   \
# 0                                           NaN         NaN
# 1                                           NaN         NaN
# 2                                           NaN         NaN
# 3                                           NaN  TOTAL SALA
# 4                            UNIDADE/ INDICADOR         NaN
# 5                                           NaN    VERMELHA
# 6                                           NaN         NaN
# 7                                           NaN         NaN
# 8                                           NaN         NaN
# 9                                   TOTAL GERAL         129
# 10                           TOTAL - HOSPITALAR          98
# 11                       FUNDAÇÃO ADRIANO JORGE           0
# 12                               FUNDAÇÃO CECON           6
# 13                FUNDAÇÃO DE MEDICINA TROPICAL           5
# 14                              FUNDAÇÃO HEMOAM           0
# 15  HOSPITAL DE COMBATE AO COVID-19 NILTON LINS           8
# 16          HOSPITAL GERAL DR. GERALDO DA ROCHA           0
# 17                HOSPITAL INFANTIL DR. FAJARDO           0
# 18         HOSPITAL PRONTO SOCORRO 28 DE AGOSTO          15
# 19        HOSPITAL PRONTO SOCORRO DELPHINA AZIZ           9
# 20           HOSPITAL PRONTO SOCORRO JOÃO LÚCIO          33
# 21        HOSPITAL PRONTO SOCORRO PLATÃO ARAÚJO           4
# 22      HOSPITAL UNIVERSITÁRIO FRANCISCA MENDES           0
# 23        HOSPITAL UNIVERSITÁRIO GETÚLIO VARGAS           0
# 24                              HPSC ZONA LESTE           2
# 25                              HPSC ZONA OESTE           3
# 26                                HPSC ZONA SUL           4
# 27                                         ICAM           0
# 28                         MATERNIDADE ALVORADA           0
# 29                        MATERNIDADE ANA BRAGA           5
# 30                  MATERNIDADE AZILDA MARREIRO           1
# 31                MATERNIDADE BALBINA MESTRINHO           2
# 32                   MATERNIDADE CHAPOT PREVOST           0
# 33                       MATERNIDADE DONA LINDÚ           1
# 34                      MATERNIDADE NAZIRA DAOU           0
#
#                        2                        3              4   \
# 0                     NaN                      NaN            NaN
# 1     SALA VERMELHA COVID  SALA VERMELHA NÃO COVID            NaN
# 2                     NaN                      NaN            NaN
# 3                     NaN                      NaN  TOTAL  LEITOS
# 4                     NaN                      NaN            NaN
# 5                     NaN                      NaN       CLINICOS
# 6   TOTAL OCUPADOS LIVRES    TOTAL OCUPADOS LIVRES            NaN
# 7                     NaN                      NaN            NaN
# 8                     NaN                      NaN            NaN
# 9                64 27 36                 65 34 30          2.322
# 10               52 27 24                 46 30 15          2.135
# 11                  0 0 0                    0 0 0             65
# 12                  5 0 5                    1 0 1            113
# 13                  1 0 1                    4 1 2            102
# 14                  0 0 0                    0 0 0             22
# 15                  8 1 7                    0 0 0            108
# 16                  0 0 0                    0 0 0             75
# 17                  0 0 0                    0 0 0             38
# 18                15 13 1                    0 0 0            234
# 19                  9 5 4                    0 0 0            249
# 20                  8 5 3                  25 25 0             51
# 21                  0 0 0                    4 2 2            125
# 22                  0 0 0                    0 0 0            131
# 23                  0 0 0                    0 0 0             59
# 24                  0 0 0                    2 0 2             69
# 25                  0 0 0                    3 1 2             49
# 26                  0 0 0                    4 0 4             41
# 27                  0 0 0                    0 0 0            100
# 28                  0 0 0                    0 0 0             33
# 29                  3 3 0                    2 1 1            138
# 30                  1 0 1                    0 0 0             38
# 31                  1 0 1                    1 0 1             92
# 32                  0 0 0                    0 0 0             18
# 33                  1 0 1                    0 0 0            135
# 34                  0 0 0                    0 0 0             50
#
#                           5      6                7       8      9   \
# 0                        NaN    NaN  LEITOS CLINICOS     NaN    NaN
# 1   LEITOS CLINICOS COVID-19    NaN              NaN     NaN    NaN
# 2                        NaN    NaN     NÃO COVID-19     NaN    NaN
# 3                        NaN    NaN              NaN     NaN    NaN
# 4                        NaN    NaN              NaN     NaN    NaN
# 5                        NaN    NaN              NaN     NaN  TOTAL
# 6      TOTAL OCUPADOS LIVRES  TOTAL         OCUPADOS  LIVRES    UTI
# 7                        NaN    NaN              NaN     NaN    NaN
# 8                        NaN    NaN              NaN     NaN    NaN
# 9                848 389 431  1.484              811     621    NaN
# 10               757 380 350  1.378              793     535    467
# 11                     3 3 0     62               10      52     12
# 12                   10 0 10    103               51      52     21
# 13                   13 11 0     89               41      35     10
# 14                     0 0 0     22               14       8      0
# 15                 108 48 38      0                0       0     26
# 16                    10 1 9     65               18      20      0
# 17                     0 0 0     38                7      31      5
# 18                192 80 112     42               42       0     52
# 19                249 162 84      0                0       0     93
# 20                    16 7 9     35               35       0     28
# 21                  62 30 32     63               58       5     31
# 22                     7 7 0    124               31      89     33
# 23                  38 10 28     21                6      15     30
# 24                    10 1 9     59               16      43     10
# 25                   13 1 12     36               13      23     10
# 26                     0 0 0     41               23      18     14
# 27                     0 0 0    100               31      69     21
# 28                     2 0 2     31               29       2      0
# 29                     6 6 0    132              117      15     35
# 30                     2 2 0     36               36       0      5
# 31                     4 3 1     88               47      39     17
# 32                     3 0 3     15               13       2      0
# 33                     7 7 0    128              108      17     10
# 34                     2 1 1     48               47       0      4
#
#                         10                          11        12  \
# 0                      NaN                         NaN       NaN
# 1   LEITOS DE UTI COVID-19  LEITOS DE UTI NÃO COVID-19       NaN
# 2                      NaN                         NaN       NaN
# 3                      NaN                         NaN       NaN
# 4                      NaN                         NaN       NaN
# 5                      NaN                         NaN       NaN
# 6                      NaN                         NaN      SALA
# 7    TOTAL OCUPADOS LIVRES       TOTAL OCUPADOS LIVRES       NaN
# 8                      NaN                         NaN  VERMELHA
# 9                      NaN                         NaN       NaN
# 10              252 166 67                  215 110 96       59%
# 11                   1 1 0                      11 1 9        --
# 12                   6 2 4                     15 3 12        0%
# 13                   6 2 2                       4 4 0       25%
# 14                   0 0 0                       0 0 0        --
# 15                26 14 11                       0 0 0       13%
# 16                   0 0 0                       0 0 0        --
# 17                   0 0 0                       5 4 1        0%
# 18                52 38 14                       0 0 0       87%
# 19                93 68 22                       0 0 0       56%
# 20                 15 12 2                     13 11 2       91%
# 21                  21 9 0                     10 10 0       50%
# 22                   3 1 2                     30 9 16        --
# 23                 18 8 10                     12 2 10        --
# 24                   0 0 0                     10 0 10        0%
# 25                   0 0 0                      10 4 6       33%
# 26                   1 1 0                      13 6 7        0%
# 27                   0 0 0                     21 0 21        --
# 28                   0 0 0                       0 0 0        --
# 29                 10 10 0                     25 24 1       80%
# 30                   0 0 0                       5 5 0        0%
# 31                   0 0 0                     17 13 1        0%
# 32                   0 0 0                       0 0 0        --
# 33                   0 0 0                     10 10 0        0%
# 34                   0 0 0                       4 4 0        --
#
#                   13      14
# 0                NaN     NaN
# 1   TAXA DE OCUPAÇÃO     NaN
# 2                NaN     NaN
# 3                NaN     NaN
# 4                NaN     NaN
# 5                NaN     NaN
# 6             LEITOS  LEITOS
# 7                NaN     NaN
# 8           CLÍNICOS  DE UTI
# 9                NaN     NaN
# 10               57%     63%
# 11               20%     18%
# 12               45%     24%
# 13               60%     75%
# 14               64%      --
# 15               56%     56%
# 16               40%      --
# 17               18%     80%
# 18               53%     78%
# 19               65%     74%
# 20               82%    144%
# 21               73%     73%
# 22               29%     30%
# 23               27%     33%
# 24               25%      0%
# 25               29%     40%
# 26               56%     50%
# 27               31%      0%
# 28               88%      --
# 29               89%     97%
# 30              100%    100%
# 31               56%     76%
# 32               76%      --
# 33               85%    100%
# 34              100%    400%

# %%
tabula.convert_into("OC_LEITOS_UND_20200603.pdf","OC_LEITOS_UND.csv",output_format = "csv",pages = "1")
dfLeitosUnd2 = pd.read_csv('OC_LEITOS_UND.csv',header=None)
dfLeitosUnd2
# Out:
#                                              0           1   \
# 0                                           NaN         NaN
# 1                                           NaN         NaN
# 2                                           NaN         NaN
# 3                                           NaN  TOTAL SALA
# 4                            UNIDADE/ INDICADOR         NaN
# 5                                           NaN    VERMELHA
# 6                                           NaN         NaN
# 7                                           NaN         NaN
# 8                                           NaN         NaN
# 9                                   TOTAL GERAL         136
# 10                           TOTAL - HOSPITALAR         105
# 11                       FUNDAÇÃO ADRIANO JORGE           0
# 12                               FUNDAÇÃO CECON           6
# 13                FUNDAÇÃO DE MEDICINA TROPICAL           5
# 14                              FUNDAÇÃO HEMOAM           0
# 15  HOSPITAL DE COMBATE AO COVID-19 NILTON LINS           8
# 16          HOSPITAL GERAL DR. GERALDO DA ROCHA           0
# 17                HOSPITAL INFANTIL DR. FAJARDO           0
# 18         HOSPITAL PRONTO SOCORRO 28 DE AGOSTO          17
# 19        HOSPITAL PRONTO SOCORRO DELPHINA AZIZ           9
# 20           HOSPITAL PRONTO SOCORRO JOÃO LÚCIO          38
# 21        HOSPITAL PRONTO SOCORRO PLATÃO ARAÚJO           4
# 22      HOSPITAL UNIVERSITÁRIO FRANCISCA MENDES           0
# 23        HOSPITAL UNIVERSITÁRIO GETÚLIO VARGAS           0
# 24                              HPSC ZONA LESTE           2
# 25                              HPSC ZONA OESTE           3
# 26                                HPSC ZONA SUL           4
# 27                                         ICAM           0
# 28                         MATERNIDADE ALVORADA           0
# 29                        MATERNIDADE ANA BRAGA           5
# 30                  MATERNIDADE AZILDA MARREIRO           1
# 31                MATERNIDADE BALBINA MESTRINHO           2
# 32                   MATERNIDADE CHAPOT PREVOST           0
# 33                       MATERNIDADE DONA LINDÚ           1
# 34                      MATERNIDADE NAZIRA DAOU           0
#
#                        2                        3              4   \
# 0                     NaN                      NaN            NaN
# 1     SALA VERMELHA COVID  SALA VERMELHA NÃO COVID            NaN
# 2                     NaN                      NaN            NaN
# 3                     NaN                      NaN  TOTAL  LEITOS
# 4                     NaN                      NaN            NaN
# 5                     NaN                      NaN       CLINICOS
# 6   TOTAL OCUPADOS LIVRES    TOTAL OCUPADOS LIVRES            NaN
# 7                     NaN                      NaN            NaN
# 8                     NaN                      NaN            NaN
# 9                67 26 41                 69 34 34          2.322
# 10               54 25 29                 51 32 18          2.135
# 11                  0 0 0                    0 0 0             65
# 12                  5 0 5                    1 1 0            113
# 13                  1 0 1                    4 0 3            102
# 14                  0 0 0                    0 0 0             22
# 15                  8 0 8                    0 0 0            108
# 16                  0 0 0                    0 0 0             75
# 17                  0 0 0                    0 0 0             38
# 18                17 17 0                    0 0 0            234
# 19                  9 2 7                    0 0 0            249
# 20                  8 5 3                  30 25 5             51
# 21                  0 0 0                    4 4 0            125
# 22                  0 0 0                    0 0 0            131
# 23                  0 0 0                    0 0 0             59
# 24                  0 0 0                    2 0 2             69
# 25                  0 0 0                    3 1 2             49
# 26                  0 0 0                    4 0 4             41
# 27                  0 0 0                    0 0 0            100
# 28                  0 0 0                    0 0 0             33
# 29                  3 1 2                    2 1 1            138
# 30                  1 0 1                    0 0 0             38
# 31                  1 0 1                    1 0 1             92
# 32                  0 0 0                    0 0 0             18
# 33                  1 0 1                    0 0 0            135
# 34                  0 0 0                    0 0 0             50
#
#                           5      6                7       8      9   \
# 0                        NaN    NaN  LEITOS CLINICOS     NaN    NaN
# 1   LEITOS CLINICOS COVID-19    NaN              NaN     NaN    NaN
# 2                        NaN    NaN     NÃO COVID-19     NaN    NaN
# 3                        NaN    NaN              NaN     NaN    NaN
# 4                        NaN    NaN              NaN     NaN    NaN
# 5                        NaN    NaN              NaN     NaN  TOTAL
# 6      TOTAL OCUPADOS LIVRES  TOTAL         OCUPADOS  LIVRES    UTI
# 7                        NaN    NaN              NaN     NaN    NaN
# 8                        NaN    NaN              NaN     NaN    NaN
# 9                838 396 413  1.484              781     650    NaN
# 10               757 391 339  1.378              767     558    467
# 11                     4 4 0     61               17      44     12
# 12                   10 0 10    103               62      41     21
# 13                    13 8 0     89               43      33     10
# 14                     0 0 0     22               20       2      0
# 15                 108 31 55      0                0       0     26
# 16                    10 1 9     65               19      19      0
# 17                     0 0 0     38                7      31      5
# 18                192 105 87     42               16      26     52
# 19                249 164 85      0                0       0     93
# 20                    16 7 9     35               33       2     28
# 21                  60 31 29     65               61       4     31
# 22                     8 8 0    123               29      90     33
# 23                  38 11 27     21                8      13     30
# 24                    10 1 9     59               19      40     10
# 25                   13 1 12     36               15      21     10
# 26                     0 0 0     41               26      15     14
# 27                     0 0 0    100               35      65     21
# 28                     2 0 2     31               29       2      0
# 29                     6 5 1    132               90      42     35
# 30                     2 2 0     36               30       2      5
# 31                     4 3 1     88               47      39     17
# 32                     3 0 3     15               15       0      0
# 33                     7 7 0    128               99      27     10
# 34                     2 2 0     48               47       0      4
#
#                         10                          11                 12  \
# 0                      NaN                         NaN                NaN
# 1   LEITOS DE UTI COVID-19  LEITOS DE UTI NÃO COVID-19   TAXA DE OCUPAÇÃO
# 2                      NaN                         NaN                NaN
# 3                      NaN                         NaN                NaN
# 4                      NaN                         NaN                NaN
# 5                      NaN                         NaN                NaN
# 6                      NaN                         NaN        SALA LEITOS
# 7    TOTAL OCUPADOS LIVRES       TOTAL OCUPADOS LIVRES                NaN
# 8                      NaN                         NaN  VERMELHA CLÍNICOS
# 9                      NaN                         NaN                NaN
# 10              252 172 73                  215 125 79            55% 56%
# 11                   2 2 0                      10 1 8             -- 32%
# 12                   6 0 6                     15 3 12            17% 55%
# 13                   6 3 1                       4 3 1             0% 61%
# 14                   0 0 0                       0 0 0             -- 91%
# 15                 26 16 9                       0 0 0             0% 36%
# 16                   0 0 0                       0 0 0             -- 42%
# 17                   0 0 0                       5 3 2             -- 18%
# 18                 52 47 5                       0 0 0           100% 52%
# 19                93 66 25                       0 0 0            22% 66%
# 20                 15 12 2                     13 11 2            79% 78%
# 21                 20 9 11                     11 10 0           100% 76%
# 22                   3 0 3                     30 9 16             -- 28%
# 23                 18 7 11                      12 5 7             -- 32%
# 24                   0 0 0                     10 0 10             0% 29%
# 25                   0 0 0                      10 3 7            33% 33%
# 26                   1 1 0                      13 4 9             0% 63%
# 27                   0 0 0                     21 20 1             -- 35%
# 28                   0 0 0                       0 0 0             -- 88%
# 29                  10 9 0                     25 24 0            40% 71%
# 30                   0 0 0                       5 5 0             0% 84%
# 31                   0 0 0                     17 10 4             0% 56%
# 32                   0 0 0                       0 0 0             -- 88%
# 33                   0 0 0                     10 10 0             0% 79%
# 34                   0 0 0                       4 4 0            -- 102%
#
#         13
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6   LEITOS
# 7      NaN
# 8   DE UTI
# 9      NaN
# 10     66%
# 11     27%
# 12     14%
# 13     75%
# 14      --
# 15     64%
# 16      --
# 17     60%
# 18     94%
# 19     72%
# 20     85%
# 21     73%
# 22     27%
# 23     40%
# 24      0%
# 25     30%
# 26     36%
# 27     95%
# 28      0%
# 29     94%
# 30    100%
# 31     59%
# 32      --
# 33    100%
# 34    400%
